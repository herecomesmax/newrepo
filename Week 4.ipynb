# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ## **JIN LI**
# I'm currently working as a math teacher and seeking opportunities to be a data analyst.

# %% [markdown]
# *I got the interest toward data science since data can have a huge impact in education technology, and I wanted to be the part of it.*

# %% [markdown]
# ### In the following cell 5, the code will read a .csv file using pandas.

# %%
# Import the pandas library
import pandas as pd

df=pd.read_csv('https://raw.githubusercontent.com/herecomesmax/herecomesmax/data/%5ENDX_2014-2022.csv', 
               usecols=['Date','Open', 'High', 'Low', 'Close', 'Volume'], index_col=0)
# PUT "CLOSE" TO THE FIRST COL
col=df.columns[[3,0,1,2,4]]
df=df[col]
df.head()
# Out:
#                   Close         Open         High          Low      Volume
# Date
# 2014-01-02  3563.570068  3575.600098  3577.030029  3553.649902  1738820000
# 2014-01-03  3538.729980  3564.939941  3567.510010  3537.610107  1667480000
# 2014-01-06  3526.959961  3539.020020  3542.520020  3512.449951  2292840000
# 2014-01-07  3557.850098  3539.290039  3562.989990  3535.500000  2278220000
# 2014-01-08  3567.540039  3558.300049  3575.149902  3551.120117  2345220000

# %% [markdown]
# ***
# * In this project I will firstly inspect the data of the stock closing price, then develop a method to analyze the trend
# 1. Statistical methods
# 2. Deep learning methods

# %% [markdown]
# |Models | Types |
# |-----------|-----------|
# | CNN   | Neural network   |
# | LSTM   | Neural network   |
# | ARIMA   | Statistical method   |

# %% [markdown]
# [Click For Raw Data](https://raw.githubusercontent.com/herecomesmax/herecomesmax/data/%5ENDX_2019-2022.csv)

# %%
# Read Image
from PIL import Image
import requests

im = Image.open(requests.get('https://upload.wikimedia.org/wikipedia/commons/thumb/9/93/LSTM_Cell.svg/2560px-LSTM_Cell.svg.png', stream = True).raw)
im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2560x1753 at 0x7F92158EE110>

# %% [markdown]
# ~~TO BE CONTINUED~~
